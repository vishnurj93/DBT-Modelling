# %%
import pandas as pd

# %%
orders = pd.read_csv('./Data/orders.csv', sep = ',')

# %%
orders.head()
# Out:
#    ORDERID   ORDERDATE    SHIPDATE        SHIPMODE CUSTOMERID  \
# 0        1  2021/11/08  2021/11/11    Second Class   CG-12520
# 1        2  2021/11/08  2021/11/11    Second Class   CG-12520
# 2        3  2021/06/12  2021/06/16    Second Class   DV-13045
# 3        4  2020/10/11  2020/10/18  Standard Class   SO-20335
# 4        5  2020/10/11  2020/10/18  Standard Class   SO-20335
#
#          PRODUCTID  ORDERCOSTPRICE  ORDERSELLINGPRICE
# 0  FUR-BO-10001798             157              262.0
# 1  FUR-CH-10000454             366              732.0
# 2  OFF-LA-10000240              13               15.0
# 3  FUR-TA-10000577             575              958.0
# 4  OFF-ST-10000760              13               22.0

# %%
orders.dtypes
# Out:
# ORDERID                int64
# ORDERDATE             object
# SHIPDATE              object
# SHIPMODE              object
# CUSTOMERID            object
# PRODUCTID             object
# ORDERCOSTPRICE         int64
# ORDERSELLINGPRICE    float64
# dtype: object

# %%
orders.isna()
# Out:
#       ORDERID  ORDERDATE  SHIPDATE  SHIPMODE  CUSTOMERID  PRODUCTID  \
# 0       False      False     False     False       False      False
# 1       False      False     False     False       False      False
# 2       False      False     False     False       False      False
# 3       False      False     False     False       False      False
# 4       False      False     False     False       False      False
# ...       ...        ...       ...       ...         ...        ...
# 9782    False      False     False     False       False      False
# 9783    False      False     False     False       False      False
# 9784    False      False     False     False       False      False
# 9785    False      False     False     False       False      False
# 9786    False      False     False     False       False      False
#
#       ORDERCOSTPRICE  ORDERSELLINGPRICE
# 0              False              False
# 1              False              False
# 2              False              False
# 3              False              False
# 4              False              False
# ...              ...                ...
# 9782           False              False
# 9783           False              False
# 9784           False              False
# 9785           False              False
# 9786           False              False
#
# [9787 rows x 8 columns]

# %%
orders.isna().sum()
# Out:
# ORDERID              0
# ORDERDATE            0
# SHIPDATE             0
# SHIPMODE             0
# CUSTOMERID           0
# PRODUCTID            0
# ORDERCOSTPRICE       0
# ORDERSELLINGPRICE    0
# dtype: int64

# %%
orders.isna().sum()
# Out:
# ORDERID              0
# ORDERDATE            0
# SHIPDATE             0
# SHIPMODE             0
# CUSTOMERID           0
# PRODUCTID            0
# ORDERCOSTPRICE       0
# ORDERSELLINGPRICE    0
# dtype: int64

# %%
orders.dropna()
# Out:
#       ORDERID   ORDERDATE    SHIPDATE        SHIPMODE CUSTOMERID  \
# 0           1  2021/11/08  2021/11/11    Second Class   CG-12520
# 1           2  2021/11/08  2021/11/11    Second Class   CG-12520
# 2           3  2021/06/12  2021/06/16    Second Class   DV-13045
# 3           4  2020/10/11  2020/10/18  Standard Class   SO-20335
# 4           5  2020/10/11  2020/10/18  Standard Class   SO-20335
# ...       ...         ...         ...             ...        ...
# 9782     9796  2021/05/21  2021/05/28  Standard Class   SH-19975
# 9783     9797  2020/01/12  2020/01/17  Standard Class   CS-12490
# 9784     9798  2020/01/12  2020/01/17  Standard Class   CS-12490
# 9785     9799  2020/01/12  2020/01/17  Standard Class   CS-12490
# 9786     9800  2020/01/12  2020/01/17  Standard Class   CS-12490
#
#             PRODUCTID  ORDERCOSTPRICE  ORDERSELLINGPRICE
# 0     FUR-BO-10001798             157              262.0
# 1     FUR-CH-10000454             366              732.0
# 2     OFF-LA-10000240              13               15.0
# 3     FUR-TA-10000577             575              958.0
# 4     OFF-ST-10000760              13               22.0
# ...               ...             ...                ...
# 9782  OFF-BI-10003429               2                4.0
# 9783  OFF-AR-10001374               7               10.0
# 9784  TEC-PH-10004977             212              235.0
# 9785  TEC-PH-10000912              13               26.0
# 9786  TEC-AC-10000487               7               10.0
#
# [9787 rows x 8 columns]

# %%
orders.isna().sum()
# Out:
# ORDERID              0
# ORDERDATE            0
# SHIPDATE             0
# SHIPMODE             0
# CUSTOMERID           0
# PRODUCTID            0
# ORDERCOSTPRICE       0
# ORDERSELLINGPRICE    0
# dtype: int64

# %%
orders.dropna(inplace=True)

# %%
orders.isna().sum()
# Out:
# ORDERID              0
# ORDERDATE            0
# SHIPDATE             0
# SHIPMODE             0
# CUSTOMERID           0
# PRODUCTID            0
# ORDERCOSTPRICE       0
# ORDERSELLINGPRICE    0
# dtype: int64

# %%
orders.to_csv('./Data/orders.csv', index = False)

# %%
orders.isna().sum()
# Out:
# ORDERID              0
# ORDERDATE            0
# SHIPDATE             0
# SHIPMODE             0
# CUSTOMERID           0
# PRODUCTID            0
# ORDERCOSTPRICE       0
# ORDERSELLINGPRICE    0
# dtype: int64

# %%
orders.count()
# Out:
# ORDERID              9787
# ORDERDATE            9787
# SHIPDATE             9787
# SHIPMODE             9787
# CUSTOMERID           9787
# PRODUCTID            9787
# ORDERCOSTPRICE       9787
# ORDERSELLINGPRICE    9787
# dtype: int64
